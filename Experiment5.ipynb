# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinav196/Python-Programming/blob/main/Experiment5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.Scan n values (0–3) and count occurrences

# %%
n = int(input("Enter number of values: "))
count = [0, 0, 0, 0]   # For 0,1,2,3

for i in range(n):
    num = int(input("Enter value (0-3): "))
    if 0 <= num <= 3:
        count[num] += 1
    else:
        print("Invalid input!")

for i in range(4):
    print(f"{i} occurred {count[i]} times")
# Out:
# Enter number of values: 5
# Enter value (0-3): 2
# Enter value (0-3): 1
# Enter value (0-3): 1
# Enter value (0-3): 0
# Enter value (0-3): 3
# 0 occurred 1 times
# 1 occurred 2 times
# 2 occurred 1 times
# 3 occurred 1 times

# %% [markdown]
# 2.Create tuple & find average

# %%
n = int(input("Enter number of values: "))
numbers = []

for i in range(n):
    num = float(input("Enter number: "))
    numbers.append(num)

t = tuple(numbers)

average = sum(t) / len(t)
print("Tuple:", t)
print("Average:", average)
# Out:
# Enter number of values: 4
# Enter number: 1
# Enter number: 2
# Enter number: 3
# Enter number: 4
# Tuple: (1.0, 2.0, 3.0, 4.0)
# Average: 2.5

# %% [markdown]
# 3.Runner-up score in list

# %%
N = int(input("Enter number of students: "))
scores = list(map(int, input("Enter scores separated by space: ").split()))

unique_scores = list(set(scores))   # Remove duplicates
unique_scores.sort()

runner_up = unique_scores[-2]
print("Runner-up score:", runner_up)
# Out:
# Enter number of students: 5
# Enter scores separated by space: 20 30 40 25 30
# Runner-up score: 30

# %% [markdown]
# 4.Dictionary of n persons

# %%
n = int(input("Enter number of persons: "))
persons = {}

for i in range(n):
    name = input("Enter name: ")
    city = input("Enter city: ")
    persons[name] = city

print("Names:", persons.keys())

print("Cities:", persons.values())

for name, city in persons.items():
    print(name, "lives in", city)

city_count = {}
for city in persons.values():
    city_count[city] = city_count.get(city, 0) + 1

print("Students in each city:", city_count)
# Out:
# Enter number of persons: 5
# Enter name: Abhinav
# Enter city: Faridabad
# Enter name: Bhavya
# Enter city: Dehradun
# Enter name: Yash
# Enter city: Mahendragarh
# Enter name: Mohd Ayan
# Enter city: Moradabad
# Enter name: Pranav
# Enter city: Patna
# Names: dict_keys(['Abhinav', 'Bhavya', 'Yash', 'Mohd Ayan', 'Pranav'])
# Cities: dict_values(['Faridabad', 'Dehradun', 'Mahendragarh', 'Moradabad', 'Patna'])
# Abhinav lives in Faridabad
# Bhavya lives in Dehradun
# Yash lives in Mahendragarh
# Mohd Ayan lives in Moradabad
# Pranav lives in Patna
# Students in each city: {'Faridabad': 1, 'Dehradun': 1, 'Mahendragarh': 1, 'Moradabad': 1, 'Patna': 1}

# %% [markdown]
# 5.Movie dictionary program

# %%
n = int(input("Enter number of movies: "))
movies = {}

for i in range(n):
    name = input("Movie name: ")
    year = int(input("Year: "))
    director = input("Director: ")
    cost = float(input("Production cost: "))
    collection = float(input("Collection made: "))

    movies[name] = {
        "year": year,
        "director": director,
        "cost": cost,
        "collection": collection
    }

for name, details in movies.items():
    print(name, details)

print("Movies released before 2015:")
for name, details in movies.items():
    if details["year"] < 2015:
        print(name)

print("Profitable movies:")
for name, details in movies.items():
    if details["collection"] > details["cost"]:
        print(name)

search_director = input("Enter director name to search: ")
for name, details in movies.items():
    if details["director"] == search_director:
        print(name)
# Out:
# Enter number of movies: 1
# Movie name: Dhurandar
# Year: 2025
# Director: Sunil
# Production cost: 20000000000
# Collection made: 400000000000
# Dhurandar {'year': 2025, 'director': 'Sunil', 'cost': 20000000000.0, 'collection': 400000000000.0}
# Movies released before 2015:
# Profitable movies:
# Dhurandar
# Enter director name to search: Sunil
# Dhurandar

# %% [markdown]
# 7.Todo List Manager (List)

# %%
tasks = []

while True:
    print("\n1.Add Task 2.View Tasks 3.Remove Task 4.Exit")
    choice = input("Enter choice: ")

    if choice == '1':
        task = input("Enter task: ")
        tasks.append(task)

    elif choice == '2':
        for i, task in enumerate(tasks):
            print(i + 1, task)

    elif choice == '3':
        num = int(input("Enter task number to remove: "))
        if 1 <= num <= len(tasks):
            tasks.pop(num - 1)
        else:
            print("Invalid task number")

    elif choice == '4':
        break
# Out:
# 1.Add Task 2.View Tasks 3.Remove Task 4.Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3041082206.py in <cell line: 0>()
#       3 while True:
#       4     print("\n1.Add Task 2.View Tasks 3.Remove Task 4.Exit")
# ----> 5     choice = input("Enter choice: ")
#       6
#       7     if choice == '1':
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %% [markdown]
# 6.Contact Book (Dictionary)

# %%
contacts = {}

while True:
    print("\n1.Add 2.Search 3.Update 4.Delete 5.Exit")
    choice = input("Enter choice: ")

    if choice == '1':
        name = input("Enter name: ")
        phone = input("Enter phone: ")
        contacts[name] = phone

    elif choice == '2':
        name = input("Enter name to search: ")
        print("Phone:", contacts.get(name, "Not found"))

    elif choice == '3':
        name = input("Enter name to update: ")
        if name in contacts:
            contacts[name] = input("Enter new phone: ")
        else:
            print("Contact not found")

    elif choice == '4':
        name = input("Enter name to delete: ")
        contacts.pop(name, "Not found")

    elif choice == '5':
        break
# Out:
# 1.Add 2.Search 3.Update 4.Delete 5.Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-140036594.py in <cell line: 0>()
#       3 while True:
#       4     print("\n1.Add 2.Search 3.Update 4.Delete 5.Exit")
# ----> 5     choice = input("Enter choice: ")
#       6
#       7     if choice == '1':
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...
