# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinav196/Python-Programming/blob/main/Experiment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Check whether the given number is divisible by 3 and 5 both

# %%
num = int(input("Enter a number: "))

if num % 3 == 0 and num % 5 == 0:
    print("The number is divisible by both 3 and 5")
else:
    print("The number is NOT divisible by both 3 and 5")
# Out:
# Enter a number: 5
# The number is NOT divisible by both 3 and 5

# %% [markdown]
# 2.Check whether a given number is multiple of five or not

# %%
num = int(input("Enter a number: "))

if num % 5 == 0:
    print("The number is a multiple of 5")
else:
    print("The number is NOT a multiple of 5")
# Out:
# Enter a number: 16
# The number is NOT a multiple of 5

# %% [markdown]
# 3.Find the greatest among two numbers

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

if a > b:
    print("Greatest number is:", a)
elif b > a:
    print("Greatest number is:", b)
else:
    print("Numbers are equal")
# Out:
# Enter first number: 5
# Enter second number: 6
# Greatest number is: 6

# %% [markdown]
# 4.Find the greatest among three numbers (assuming no two values are same)

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a > b and a > c:
    print("Greatest number is:", a)
elif b > a and b > c:
    print("Greatest number is:", b)
else:
    print("Greatest number is:", c)
# Out:
# Enter first number: 5
# Enter second number: 6
# Enter third number: 7
# Greatest number is: 7

# %% [markdown]
# 5.Check whether quadratic equation has real or imaginary roots & display roots

# %%
import math

a = float(input("Enter value of a: "))
b = float(input("Enter value of b: "))
c = float(input("Enter value of c: "))

discriminant = b**2 - 4*a*c

if discriminant > 0:
    print("Roots are real and distinct")
    root1 = (-b + math.sqrt(discriminant)) / (2*a)
    root2 = (-b - math.sqrt(discriminant)) / (2*a)
    print("Root1 =", root1)
    print("Root2 =", root2)

elif discriminant == 0:
    print("Roots are real and equal")
    root = -b / (2*a)
    print("Root =", root)

else:
    print("Roots are imaginary")
    real_part = -b / (2*a)
    imaginary_part = math.sqrt(-discriminant) / (2*a)
    print("Root1 =", real_part, "+", imaginary_part, "i")
    print("Root2 =", real_part, "-", imaginary_part, "i")
# Out:
# Enter value of a: 2
# Enter value of b: 5
# Enter value of c: 9
# Roots are imaginary
# Root1 = -1.25 + 1.713913650100261 i
# Root2 = -1.25 - 1.713913650100261 i

# %% [markdown]
# 6.Check whether a given year is a leap year or not

# %%
year = int(input("Enter a year: "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("It is a Leap Year")
else:
    print("It is NOT a Leap Year")
# Out:
# Enter a year: 2016
# It is a Leap Year

# %% [markdown]
# 7.Program to display next date of the calendar

# %%
day = int(input("Enter day: "))
month = int(input("Enter month: "))
year = int(input("Enter year: "))


days_in_month = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]


if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    days_in_month[1] = 29

day += 1

if day > days_in_month[month - 1]:
    day = 1
    month += 1

    if month > 12:
        month = 1
        year += 1

print("Next Date is:")
print("day =", day, "month =", month, "year =", year)
# Out:
# Enter day: 5
# Enter month: 5
# Enter year: 2025
# Next Date is:
# day = 6 month = 5 year = 2025

# %% [markdown]
# 8.Print the grade sheet of a student for the given range of cgpa. Scan marks of five subjects and calculate the percentage.

# %%
name = input("Enter Name: ")
roll = input("Enter Roll Number: ")
sapid = input("Enter SAP ID: ")
sem = input("Enter Semester: ")
course = input("Enter Course: ")

print("\nEnter Marks of 5 Subjects (out of 100):")
pds = float(input("PDS: "))
python = float(input("Python: "))
chemistry = float(input("Chemistry: "))
english = float(input("English: "))
physics = float(input("Physics: "))

total = pds + python + chemistry + english + physics
percentage = total / 5

cgpa = percentage / 10

if 0 <= cgpa <= 3.4:
    grade = "F"
elif 3.5 <= cgpa <= 5.0:
    grade = "C+"
elif 5.1 <= cgpa <= 6.0:
    grade = "B"
elif 6.1 <= cgpa <= 7.0:
    grade = "B+"
elif 7.1 <= cgpa <= 8.0:
    grade = "A"
elif 8.1 <= cgpa <= 9.0:
    grade = "A+"
elif 9.1 <= cgpa <= 10.0:
    grade = "O (Outstanding)"
else:
    grade = "Invalid CGPA"

print("\n---------- GRADE SHEET ----------")
print("Name:", name)
print("Roll Number:", roll, "SAPID:", sapid)
print("Sem:", sem, "Course:", course)

print("\nSubject Name : Marks")
print("PDS :", pds)
print("Python :", python)
print("Chemistry :", chemistry)
print("English :", english)
print("Physics :", physics)

print("\nPercentage:", round(percentage, 2), "%")
print("CGPA:", round(cgpa, 2))
print("Grade:", grade)
# Out:
# Enter Name: Pranav
# Enter Roll Number: 590029253
# Enter SAP ID: 590029253
# Enter Semester: 2
# Enter Course: B.Tech
#
# Enter Marks of 5 Subjects (out of 100):
# PDS: 50
# Python: 40
# Chemistry: 35
# English: 35
# Physics: 50
#
# ---------- GRADE SHEET ----------
# Name: Pranav
# Roll Number: 590029253 SAPID: 590029253
# Sem: 2 Course: B.Tech
#
# Subject Name : Marks
# PDS : 50.0
# Python : 40.0
# Chemistry : 35.0
# English : 35.0
# Physics : 50.0
#
# Percentage: 42.0 %
# CGPA: 4.2
# Grade: C+
